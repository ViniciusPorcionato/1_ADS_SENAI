# %% [markdown]
# # Isso é um titulo de nivel 1

# %% [markdown]
# ##Isso é um titulo de nivel 2

# %% [markdown]
# ###Isso é um titulo de nivel 3

# %% [markdown]
# #Primeiro Programa

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
lado1 = int(input("Digite o tamanho da largura do terreno:"))
lado2 = int(input("Digite o tamanho da altura do terreno:"))
area = lado1 * lado2
print(f"A area do terreno de largura: {lado1} com comprimeto: {lado2} é : {area}")
# Out:
# Digite o tamanho da largura do terreno:12
# Digite o tamanho da altura do terreno:50
# A area do terreno de largura: 12 com comprimeto: 50 é : 600
