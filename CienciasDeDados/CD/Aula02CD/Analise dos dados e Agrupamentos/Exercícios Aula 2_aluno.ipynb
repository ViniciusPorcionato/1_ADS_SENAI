# %% [markdown]
# #Exercícios Aula 2

# %% [markdown]
# ## Exercício 1)
#
# 1. Carregue os dados de "world_population.csv" para a realização do exercício.

# %% [markdown]
# ## Exercício 2)
#
# Visualize as 5 primeiras linhas do seu conjunto de dados

# %% [markdown]
# Quais os tipos de dados que temos nas colunas desse conjunto de dados? Existe alguma coluna que visualmente possui valores inteiros (`int64`) ou reais (`float64`), mas está aparecendo como `object`?

# %% [markdown]
# ## Exercício 3)
#
# Remova as colunas CCA3, Capital e Rank desse conjunto de dados

# %% [markdown]
# Confirme se realmente as colunas foram removidas

# %% [markdown]
# Verificar a existencia de valores nulos

# %% [markdown]
# ## Exercício 4)
#
# Quais são os valores únicos para os continentes? Todos os continentes estão incluídos nesse conjunto de dados?

# %% [markdown]
# Crie uma coluna com a taxa de crescimento entre os anos de 2022 e 2020

# %% [markdown]
# Reorganizar as colunas dos dados para que a nova coluna criada fique ao lado de "Growth Rate"

# %% [markdown]
# Existe uma diferença entre a taxa de crescimento calculada e o "Growth Rate"?

# %% [markdown]
# ## Exercício 5)
#
# Crie um agrupamento para visualizar a média do crescimento populacional entre 2022 e 2020 em cada um dos continentes do conjunto de dados. Qual foi o continente que tinha a maior população?

# %% [markdown]
# Para o continente Africano, qual é o pais com a maior população em 2022?
#
# Dica: Use o comando `max()` após criar o seu DataFrame verifique essa informação.

# %% [markdown]
# ##Exercício 6

# %% [markdown]
# Carregar o conjunto de dados "diabetes.csv"

# %% [markdown]
# Para esse conjunto de dados verifique quantas pessoas testaram positivo para diabetes plotando um gráfico da barras. Existem mais exemplos de pessoas que testaram positivo ou negativo?

# %% [markdown]
# Verifique a idade média das pessoas que testaram positivo e negativo para a diabetes a partir de um agrupamento
